# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
from metodo_limpeza.clean import *

# %% [markdown]
# # Prova Prática 1

# %% [markdown]
# ## Análise de Séries Temporais
# ### Daniel Lima Viegas - 14/0168109

# %% [markdown]
# ### Questão 1

# %% [markdown]
# 1.

# %%
df = limpa_london('london_analysis/Matter2013-London.csv')
plt.plot(df.Maximo)
